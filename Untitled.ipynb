# %%
import os
from dotenv import load_dotenv
import sys 

load_dotenv()

os.environ["SUPABASE_URL"] = 'https://cavhkpwbmesinizbfxst.supabase.co'                                                                                                                                                                                                           
os.environ["SUPABASE_SERVICE_KEY"] = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImNhdmhrcHdibWVzaW5pemJmeHN0Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc3MjEyMjYwMywiZXhwIjoyMDg3Njk4NjAzfQ.eg0SuAlT9FStN2ZaQkJiparxrd8K9ZCS9n0N1NOoaFw'                                                                                                                                                                                                           

# Import the function (adjust path as needed)                                                                                                                                                                                                                               
                                                                                                                                                                                                                                                                 
sys.path.insert(0, 'website/scripts')                                                                                                                                                                                                                                       
from update_regime_supabase import update_all                                                                                                                                                                                                                               

# Update everything                                                                                                                                                                                                                                                         
update_all(regime_s, z_spread_smoothed, "public/images/regime_speedometer.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-faf99d738841> in <module>
#      14
#      15 # Update everything
# ---> 16 update_all(regime_s, z_spread_smoothed, "public/images/regime_speedometer.png")
#
# NameError: name 'regime_s' is not defined

# %%
import sys                                                                                                                                                                                                                                                                  
sys.path.insert(0, '/Users/kmf229/Documents/Trading/Substack/website/scripts')                                                                                                                                                                                              
                                                                                                                                                                                                                                                                              
from update_regime_supabase import update_all

update_all(regime_s, z_spread_smoothed, "path/to/speedometer.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-49c3a073e39b> in <module>
#       4 from update_regime_supabase import update_all
#       5
# ----> 6 update_all(regime_s, z_spread_smoothed, "path/to/speedometer.png")
#
# NameError: name 'regime_s' is not defined
